# %%
# Énoncé : 

# For this part, we will use the following dataset: sales_predictions.csv.
# 1. Import usual librairies
# 2. Use a sample() to select 25 random entries from the dataset
# 3. Using relplot(), build a chart that will allow you to see the price evolution over time. What can you see?
# 4. Using the pd.to_datetime() function, convert your date column to datetime
# 5. Retry doing your visualization. What do you see?

# %%
import pandas as pd
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("./src/sales_predictions.csv")
data.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
data.shape
# Out:
# (2935849, 6)

# %%
data = data.sample(25)
data.head()
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 2441116  01.02.2015              25       49     1858      1199.0
# 2712033  27.06.2015              29       48    19291       999.0
# 921223   05.09.2013               8       59     1937       599.0
# 1684131  22.05.2014              16       57     1035       299.0
# 1715631  14.06.2014              17       25    10331       149.0
#
#          item_cnt_day
# 2441116           1.0
# 2712033           1.0
# 921223            1.0
# 1684131           1.0
# 1715631           1.0

# %%
sns.relplot(x="date", y="item_price", data = data, kind="line", height = 5, aspect = 3)

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
sns.relplot(x="date", y="item_price", data = data, kind="line", height = 5, aspect = 3)
