# %%
# Énoncé : 

# Working on IBM_HR_ATTRITION.csv.
# 1. Import usual librairies
# 2. We would like to know the probability of leaving the business in relation to the distance from home. Use lmplot() to view this. What can you conclude?
# 3. Try it this time with the number of years spent with the Manager (YearsWithCurrManager), what can you conclude?
# 4. Attempt to look at other variables, including YearsAtCompany & YearsWithCurrManager

# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("./src/IBM_HR_ATTRITION.csv")
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data.Attrition.unique()
# Cette méthode .unique() permet de retourner une liste contenant les valeurs uniques de la colonne Attrition
# Ainsi je vérifie si on a bien que des Yes et des No
# Note : La liste retournée n'est pas triée !
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data2 = data.copy()

# %%
data2.Attrition.value_counts()
# Autre façon de faire pour voir si Attrition contient seulement des Yes et des No (pas de cellules vides)
# Avec un .value_count() on peut voir quelles valeurs on a
# Ainsi on voit qu'on a soit des Yes soit des No
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
data2['Attrition'] = data2['Attrition'].apply(lambda x: 1 if x.lower() == "yes" else 0)
# Je remplace la value de l'attrition par des valeurs numériques : 1 ou 0 pour Yes ou No
# Je remplace des données qualitatives par du quantitatif

# %%
sns.lmplot(x="DistanceFromHome", y="Attrition", data=data2, logistic=True, scatter_kws={"alpha":.05})
# scatter_kws permet de mettre une épaisseur autour de la droite
# logistic=True permet d'avoir une courbe et non un tracé tout droit

# %%
sns.lmplot(x="YearsWithCurrManager", y="Attrition", data=data2, logistic=True, scatter_kws={"alpha":.05})

# %%
sns.lmplot(x="YearsAtCompany", y="Attrition", data=data2, logistic=True, scatter_kws={"alpha":.05})
